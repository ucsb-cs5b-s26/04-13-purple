# %%
from datascience import *
import numpy as np

# Load the CSV file
my_data = Table.read_table('credit-card-clients-default.csv')

# View the first few rows
my_data.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Unnamed: 0</th> <th>X1</th> <th>X2</th> <th>X3</th> <th>X4</th> <th>X5</th> <th>X6</th> <th>X7</th> <th>X8</th> <th>X9</th> <th>X10</th> <th>X11</th> <th>X12</th> <th>X13</th> <th>X14</th> <th>X15</th> <th>X16</th> <th>X17</th> <th>X18</th> <th>X19</th> <th>X20</th> <th>X21</th> <th>X22</th> <th>X23</th> <th>Y</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ID        </td> <td>LIMIT_BAL</td> <td>SEX </td> <td>EDUCATION</td> <td>MARRIAGE</td> <td>AGE </td> <td>PAY_0</td> <td>PAY_2</td> <td>PAY_3</td> <td>PAY_4</td> <td>PAY_5</td> <td>PAY_6</td> <td>BILL_AMT1</td> <td>BILL_AMT2</td> <td>BILL_AMT3</td> <td>BILL_AMT4</td> <td>BILL_AMT5</td> <td>BILL_AMT6</td> <td>PAY_AMT1</td> <td>PAY_AMT2</td> <td>PAY_AMT3</td> <td>PAY_AMT4</td> <td>PAY_AMT5</td> <td>PAY_AMT6</td> <td>default payment next month</td>
#         </tr>
#         <tr>
# ...
